# %%
import pandas as pd

# %%
df = pd.read_csv("database.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638454 entries, 0 to 638453
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Record ID              638454 non-null  int64
#  1   Agency Code            638454 non-null  object
#  2   Agency Name            638454 non-null  object
#  3   Agency Type            638454 non-null  object
#  4   City                   638454 non-null  object
#  5   State                  638454 non-null  object
#  6   Year                   638454 non-null  int64
#  7   Month                  638454 non-null  object
#  8   Incident               638454 non-null  int64
#  9   Crime Type             638454 non-null  object
#  10  Crime Solved           638454 non-null  object
#  11  Victim Sex             638454 non-null  object
#  12  Victim Age             638454 non-null  int64
#  13  Victim Race            638454 non-null  object
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
df.head()
# Out:
#    Record ID Agency Code Agency Name       Agency Type       City   State  \
# 0          1     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 1          2     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 2          3     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 3          4     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 4          5     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
#
#    Year    Month  Incident              Crime Type Crime Solved Victim Sex  \
# 0  1980  January         1  Murder or Manslaughter          Yes       Male
# 1  1980    March         1  Murder or Manslaughter          Yes       Male
# 2  1980    March         2  Murder or Manslaughter           No     Female
# 3  1980    April         1  Murder or Manslaughter          Yes       Male
# 4  1980    April         2  Murder or Manslaughter           No     Female
#
# ...

# %%
df1 = df.copy()

# %%
df1.columns = df1.columns.str.replace(" ", "_")

# %%
df1[
    (df1["Crime_Solved"] == "No") &
     (df1["Year"] == 2010) &
    (df1["Month"] == 'January')
]
# Out:
#         Record_ID Agency_Code Agency_Name       Agency_Type        City  \
# 564769     564770     AK00101   Anchorage  Municipal Police   Anchorage
# 564921     564922     AL03102     Gadsden  Municipal Police      Etowah
# 564973     564974     AL05201     Decatur  Municipal Police      Morgan
# 564993     564994     AL06301  Tuscaloosa  Municipal Police  Tuscaloosa
# 565002     565003     AR00100    Arkansas           Sheriff    Arkansas
# ...           ...         ...         ...               ...         ...
# 579583     579584     WA03204     Spokane  Municipal Police     Spokane
# 579607     579608     WA03900      Yakima           Sheriff      Yakima
# 579633     579634     WASPD00     Seattle  Municipal Police        King
# 579635     579636     WASPD00     Seattle  Municipal Police        King
# 579832     579833     WV01702  Clarksburg  Municipal Police    Harrison
#
#                 State  Year    Month  Incident              Crime_Type  \
# ...

# %%
df1["Crime_Type"].unique()
# Out:
# array(['Murder or Manslaughter', 'Manslaughter by Negligence'],
#       dtype=object)

# %%
df1[['Perpetrator_Sex','Victim_Count']]
# Out:
#        Perpetrator_Sex  Victim_Count
# 0                 Male             0
# 1                 Male             0
# 2              Unknown             0
# 3                 Male             0
# 4              Unknown             0
# ...                ...           ...
# 638449         Unknown             0
# 638450            Male             0
# 638451          Female             0
# 638452            Male             0
# 638453          Female             0
#
# [638454 rows x 2 columns]

# %%
df1.plot(y="Victim_Count")
# Out:
# <AxesSubplot:>

# %%
df_not_solv_gp_yr.columns = ['not_solved'] 
# df_not_solv_gp_yr.drop('Not Solved', axis = 1, inplace = True)

# %%
df_solv_gp_yr = df_solv.\
    groupby('Year')['Crime Solved'].\
    agg(['count']).\
    rename({'count' : 'solved'}, axis = 1)
# df_solv_gp_yr.head()

# %%
df_not_solv_gp_yr.shape, df_solv_gp_yr.shape
# Out:
# ((35, 1), (35, 1))

# %%
df_solv_noSov = pd.DataFrame({'solved' : df_solv_gp_yr['solved'], 'not_solved' : df_not_solv_gp_yr['not_solved']}) 
df_solv_noSov.head()
# Out:
#       solved  not_solved
# Year
# 1980   16729        6363
# 1981   15788        5420
# 1982   15060        5484
# 1983   14515        5138
# 1984   13245        4848

# %%
df_solv_noSov.plot.barh(figsize =  (10, 10) )
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
df2_grp_year_solved_weapon = df[['Year','Weapon', 'Crime Solved']].groupby(['Year', 'Crime Solved'])['Weapon'].value_counts().unstack('Weapon')

# %%
# df2_grp_year_solved_weapon['solved'] = 
index_list = df2_grp_year_solved_weapon.index.values.tolist()
year = []
solved = []
for item in index_list :
    y = item[0]
    s = item[1]
    year.append(y)
    solved.append(s)

# %%
df2_grp_year_solved_weapon.head()
# Out:
# Weapon             Blunt Object  Drowning  Drugs  Explosives  Fall   Fire  \
# Year Crime Solved
# 1980 No                   706.0      14.0    3.0         8.0   3.0  124.0
#      Yes                 1691.0      36.0   11.0        14.0  14.0  173.0
# 1981 No                   542.0      18.0    4.0        12.0   2.0   89.0
#      Yes                 1644.0      41.0   19.0         4.0   9.0  178.0
# 1982 No                   642.0      14.0    8.0         7.0   NaN  106.0
#
# Weapon             Firearm   Gun  Handgun   Knife  Poison   Rifle  Shotgun  \
# Year Crime Solved
# 1980 No              499.0  22.0   2792.0  1076.0     3.0   124.0    299.0
#      Yes             364.0  31.0   8053.0  3179.0    14.0  1082.0   1486.0
# 1981 No              426.0  52.0   2419.0   935.0     NaN    96.0    212.0
#      Yes             356.0  32.0   7533.0  3010.0    13.0   952.0   1458.0
# 1982 No              480.0  27.0   2318.0   962.0     7.0    84.0    232.0
#
# ...

# %%
df2_grp_year_solved_weapon['year']=year
df2_grp_year_solved_weapon['solved']=solved
df2_grp_year_solved_weapon.head()
# Out:
# Weapon             Blunt Object  Drowning  Drugs  Explosives  Fall   Fire  \
# Year Crime Solved
# 1980 No                   706.0      14.0    3.0         8.0   3.0  124.0
#      Yes                 1691.0      36.0   11.0        14.0  14.0  173.0
# 1981 No                   542.0      18.0    4.0        12.0   2.0   89.0
#      Yes                 1644.0      41.0   19.0         4.0   9.0  178.0
# 1982 No                   642.0      14.0    8.0         7.0   NaN  106.0
#
# Weapon             Firearm   Gun  Handgun   Knife  Poison   Rifle  Shotgun  \
# Year Crime Solved
# 1980 No              499.0  22.0   2792.0  1076.0     3.0   124.0    299.0
#      Yes             364.0  31.0   8053.0  3179.0    14.0  1082.0   1486.0
# 1981 No              426.0  52.0   2419.0   935.0     NaN    96.0    212.0
#      Yes             356.0  32.0   7533.0  3010.0    13.0   952.0   1458.0
# 1982 No              480.0  27.0   2318.0   962.0     7.0    84.0    232.0
#
# ...

# %%
df2_grp_year_solved_weapon[df2_grp_year_solved_weapon['solved']=='No'].\
plot.barh(x='year', figsize =  (10, 10), stacked=True)
# Out:
# <AxesSubplot:ylabel='year'>

# %%
df2_grp_year_solved_weapon[df2_grp_year_solved_weapon['solved']=='Yes'].\
plot.barh(x='year', figsize =  (10, 10), stacked=True)
# Out:
# <AxesSubplot:ylabel='year'>

# %%
from matplotlib import pyplot as plt
#fig, axes = plt.subplots(nrows=1, ncols=2)
figure=plt.figure(figsize=(20,20))
#plt.subplot(2,1,1)
df2_grp_year_solved_weapon[df2_grp_year_solved_weapon['solved']=='Yes'].\
plot.barh(x='year', stacked=True) #no need to specify for first axis
#plt.subplot(2,1,2)
df2_grp_year_solved_weapon[df2_grp_year_solved_weapon['solved']=='No'].\
plot.barh(x='year', stacked=True)
# Out:
# <AxesSubplot:ylabel='year'>

# %%
df2_grp_year_solved_weapon.plot.barh(x='year', figsize =  (16, 16), stacked=True)
# Out:
# <AxesSubplot:ylabel='year'>

# %%
df2_grp_year_solved_weapon.columns
# Out:
# Index(['Blunt Object', 'Drowning', 'Drugs', 'Explosives', 'Fall', 'Fire',
#        'Firearm', 'Gun', 'Handgun', 'Knife', 'Poison', 'Rifle', 'Shotgun',
#        'Strangulation', 'Suffocation', 'Unknown'],
#       dtype='object', name='Weapon')

# %%
df2_gr_cr_sv.plot.barh(figsize =  (10, 10) )
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
df_not_solv = df[df['Crime Solved']=='No']
df_solv = df[df['Crime Solved']=='Yes']

df_not_solv_gp_yr = df_not_solv.groupby('Year')['Crime Solved'].agg(['count'])
 

rename(columns={1: "Not Solved"})
count = df_not_solv_gp_yr['count']
df_not_solv_gp_yr['Not Solved'] = count 
df_not_solv_gp_yr



# df_not_solv.rename({2: "Not Solved"}, axis='columns')
# df_not_solv
# df['Address'] = address 

# df_solv = df[df['Crime Solved']=='Yes']
# df_solv.groupby('Year')['Crime Solved'].agg(['count'])
# df_solv.rename({2: "Solved"}, axis='columns')
# df_solv
# Out:
#       count  Not Solved
# Year
# 1980   6363        6363
# 1981   5420        5420
# 1982   5484        5484
# 1983   5138        5138
# 1984   4848        4848
# 1985   4763        4763
# 1986   5305        5305
# 1987   5310        5310
# 1988   5388        5388
# 1989   5689        5689
# 1990   6245        6245
# 1991   7336        7336
# 1992   7912        7912
# 1993   7900        7900
# 1994   7365        7365
# 1995   6809        6809
# 1996   5881        5881
# 1997   5667        5667
# 1998   4770        4770
# 1999   4395        4395
# 2000   4464        4464
# 2001   4757        4757
# 2002   4984        4984
# 2003   5280        5280
# 2004   5078        5078
# 2005   5229        5229
# 2006   5349        5349
# 2007   5514        5514
# 2008   5057        5057
# 2009   4625        4625
# 2010   4415        4415
# 2011   4313        4313
# 2012   4458        4458
# 2013   4390        4390
# 2014   4381        4381

# %%
df_not_solv.columns

# %%
df_not_solv.index

# %%
df1['Crime_Type'].value_counts().plot(kind='barh',color=['r','g','b','c','y','brown'])
# Out:
# <AxesSubplot:>

# %%
df1['Agency_Type'].value_counts().plot(kind='barh',color=['r','g','b','c','y','brown'])
# Out:
# <AxesSubplot:>

# %%
df1['Perpetrator_Sex'].value_counts().plot(kind='barh',color=['r','g','b','c','y','brown'])
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(2, 1)
df1.Victim_Sex.value_counts().plot(title="Meurtre Par Sexe",y=df1.Victim_Sex.value_counts(),kind="pie",figsize=(20,20),autopct='%.2f%%',colormap="tab20c", ax=ax1)

df1.Relationship.value_counts().plot(title="Relation meutrier victime (General)",kind="pie",figsize=(20,20),autopct='%.2f%%',colormap="tab20c", ax=ax2)
# Out:
# <AxesSubplot:title={'center':'Relation meutrier victime (General)'}, ylabel='Relationship'>

# %%
def add_value_labels(ax, spacing=5, fontsize=20,ascending=False):
    for rect in ax.patches:
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2
        space = spacing
        va = 'bottom'
        if y_value < 0:
            space *= -1
            va = 'top'
        label = "{:.1f}".format(y_value)
        ax.annotate(
            label,                      
            (x_value, y_value),         
            xytext=(0, space),          
            textcoords="offset points", 
            ha='center',                
            va=va, fontsize=fontsize)                          
    return ax

# %%
months = df1.Month.value_counts().plot(title="Assassinations nested in months",kind="bar",x=df1.State.unique(), y=df1.Month.value_counts().mean(), figsize=(20,20),colormap="tab20c")
add_value_labels(months, spacing=5, fontsize=10,ascending=False)
# Out:
# <AxesSubplot:title={'center':'Assassinations nested in months'}>

# %%
graph = df1["Year"].value_counts().plot(title="Number of nested killings per year (1993-2014)",kind="bar",x=df1.Year, y=df1["Year"].value_counts(), figsize=(20,20))
add_value_labels(graph, spacing=5, fontsize=10)
# Out:
# <AxesSubplot:title={'center':'Number of nested killings per year (1993-2014)'}>

# %%
fem= df1['Perpetrator_Sex']== 'female'
fem.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Perpetrator_Sex, dtype: bool
